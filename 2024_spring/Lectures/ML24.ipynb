# %%
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader

# %%
#torch.cuda.is_available()
#device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
housing = pd.read_csv("https://raw.githubusercontent.com/ageron/handson-ml2/master/datasets/housing/housing.csv")
housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
housing.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
housing.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = \
    train_test_split(housing.drop(columns=['median_house_value']), \
                     housing['median_house_value'], stratify=housing['ocean_proximity'])

# %%
# X_train.iloc[:,-1].unique().tolist().index()
X_train.iloc[1,-1]
# Out:
# 'INLAND'

# %%
# train_mean = X_train.mean(axis=0).values
# train_std = X_train.std(axis=0).values
# y_mean = y_train.mean()
# y_std = y_train.std()
